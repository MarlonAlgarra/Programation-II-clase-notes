# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
dt = 0.05
t = np.arange(-2.0, 4.0, dt)
limite = 8
n = 10
r = np.random.randint(-limite,limite+1,n) 
r2= np.random.randint(-limite,limite+1,n) 
print('Datos aleatorios\n',r,r2)
# Out:
# Datos aleatorios
#  [-8  3 -2  5  1  8 -1  8 -4  2] [-4 -1  1 -5 -4 -4  1  7  5  6]

# %%
fig, ax = plt.subplots()
ax.plot(r,'o-')
ax.plot(r2,'o-')
ax.set(xlabel='Eje X', ylabel='Eje Y',title='Números aleatorios')
ax.grid(); ax.axis([0,n,-limite-1,limite+1])
# Out:
# [0, 10, -9, 9]

# %%
def cruces(arreglo,promedio):
    ''' Función para calcular los valores x de cruce entre el arreglo y el valor cte promedio '''
    x = []
    s = arreglo > promedio
    for i in range(len(arreglo)-1):
        if s[i] != s[i+1]:  # si hay cambio de valor true-false False-True
            # calcular ec de recta -> y0 = m * x0 + b
            m = arreglo[i+1]-arreglo[i]
            b = arreglo[i] - m * i
            x0 = (promedio-b)/m
            x.append(x0)
    return x

# %%
for i in range(0,len(r)-1):
    m1=((r[i+1]-r[i])/(i+1)-i)
    print(m1)
    m2=((r2[i+1]-r2[i])/(i+1)-i)
    xf=((r2[i]-i*m2+i*m1-r[i]/(m1-m2))
    #y=(m*(xf-i)+r[i])
    #ax.plot(xf,y)
# Out:
#   File "<ipython-input-19-5d17979efdcf>", line 8
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
np.sign(-5)
# Out:
# -1
