# %%
from claseprog2 import *
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
print('hi')
# Out:
# hi

# %%
figura1=Figura()
print(figura1.x)
print(figura1.y)
print(figura1.arg)
fig, ax = plt.subplots()
ax.plot(figura1.x,figura1.y)
# Out:
# [-1, 1, 0, -1]
# [0, 0, 1.5, 0]
# 1

# %%
print(figura1.rotar(10))
print('Fin ok')
# Out:
# ([0.8390715290764524, -0.8390715290764524, 0.8160316663340547, 0.8390715290764524], [0.5440211108893698, -0.5440211108893698, -1.2586072936146786, 0.5440211108893698])
# Fin ok
